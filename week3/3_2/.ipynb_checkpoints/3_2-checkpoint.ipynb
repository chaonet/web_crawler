# %%
from pymongo import MongoClient
import charts

client = MongoClient('localhost', 27017, connect=False)
ganji = client['ganji']
json_db = ganji['json_db']
# Out:
# Server running in the folder /Users/chao/Desktop/projects/web_crawler/week3/3_2 at 127.0.0.1:56806

# %%
for i in info_detail.find().limit(300):
    print i
# Out:
# {u'title': u'\u957f\u57ce\u5bbd\u5e26 \u8fd8\u52695\u4e2a\u6708,300\u5143\u8f6c - 300\u5143', u'url': u'http://bj.ganji.com/diannao/2060733684x.htm', u'price': 300, u'location': [u' \u5317\u4eac', u'\u671d\u9633', u'\u828d\u836f\u5c45'], u'date': u'05-01 21:31', u'_id': ObjectId('574c5d98e0028266b537fdad'), u'condition': None, u'goods_type': u'\u5bbd\u5e26'}
# {u'title': u'\u8d39\u96ea\u5b66\u6b65\u8f66\u591a\u529f\u80fd\u72ee\u5b50\u5b66\u6b65\u63a8\u8f66 \u5a74\u513f\u63a8\u8f66y9854\u65e9\u6559\u73a9\u5177 - 120\u5143', u'url': u'http://bj.ganji.com/yingyouyunfu/2149551968x.htm', u'price': 120, u'location': [u' \u5317\u4eac', u'\u6d77\u6dc0', u'\u5b66\u9662\u8def'], u'date': u'05-20 15:56', u'_id': ObjectId('574c5d98e0028266b837fdad'), u'condition': None, u'goods_type': u'\u5b66\u6b65\u8f66'}
# ...
